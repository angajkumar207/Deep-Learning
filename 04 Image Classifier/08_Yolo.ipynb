# %% [markdown]
# ### **YOLO** : *****YOLO stands for "You Only Look Once." It is one of the most popular and influential Deep Learning (DL) architectures used for real-time object detection*****
# - Image Classification with YOLOv11
#
# - working with  YOLOv11 models
#   - Pretrained
#   - Transfer Learning

# %% [markdown]
# Install YOLO

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolo11m-cls.pt") ## Load a pretrained model

# %%
from torch import result_type
### Predict with the model
results = model("/content/birds for pro.jpg")
# Out:
# image 1/1 /content/birds for pro.jpg: 224x224 macaw 0.95, sulphur-crested_cockatoo 0.02, jay 0.00, lorikeet 0.00, banana 0.00, 242.9ms
# Speed: 31.8ms preprocess, 242.9ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)

# %%
from IPython.display import Image
display(Image(filename='birds for pro.jpg'))

# %%
from requests.models import Response
import requests
def download_image_from_url(url, save_path):

  try:
    response = requests.get(url, stream=True)
    response.raise_for_status()

    with open(save_path, 'wb') as out_file:
      out_file.write(response.content)
    print(f"Image download successfully to {save_path}")
  except requests.exceptions.RequestException as e:
    print(f"Error Downloading image {e}")

# %%
### Exmple
download_image_from_url("https://img.magnific.com/free-photo/boiga-snake-dendrophila-yellow-ringed_488145-196.jpg?semt=ais_hybrid&w=740&q=80",'snakes.jpeg')
# Out:
# Image download successfully to snakes.jpeg

# %%
display(Image(filename='snakes.jpeg'))

# %% [markdown]
# angaj
